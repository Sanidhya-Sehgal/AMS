# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanidhya-Sehgal/AMS/blob/master/course_3/gdm_lab_3_5_tune_hyperparameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > <p><small><small>This Notebook is made available subject to the licence and terms set out in the <a href = "http://www.github.com/google-deepmind/ai-foundations">AI Research Foundations Github README file</a>.

# %% [markdown]
# <img src="https://storage.googleapis.com/dm-educational/assets/ai_foundations/GDM-Labs-banner-image-C3-white-bg.png">

# %% [markdown]
# # Lab: Tune Hyperparameters
#
# <a href='https://colab.research.google.com/github/google-deepmind/ai-foundations/blob/master/course_3/gdm_lab_3_5_tune_hyperparameters.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>
#
# Optimize hyperparameters to avoid overfitting.
#
# 15 minutes

# %% [markdown]
# ## Overview
#
# When you train a model, it adjusts its parameters such that it learns the patterns in the training data. However, in order for it to do this most effectively, you, as a model developer, have to find the best settings of the model and the training process. For example, you have to decide how many layers the model should have and for how long the model should be trained. These types of parameters that are configured before a model begins training are called **hyperparameters**. In this lab, you will explore how changing two types of hyperparameters affects how well the model can learn and generalize.

# %% [markdown]
# ### What you will learn:
#
# By the end of this lab, you will:
# * Understand how changing the number of layers of a model and changing the number of neurons within a layer affects model training.

# %% [markdown]
# ### Tasks
#
# In this lab, you will again use the dataset from the previous labs in which the classifier aims to predict the next token from the three words "mat", "apple", and "bank". You will then train models with different hyperparameters and investigate their learning behavior through inspecting the learning curves, their accuracy, and their decision boundaries.
#
# **In this lab, you will**:
# * Load the dataset of 2-dimensional embeddings.
# * Initialize different MLP models.
# * Train the models and plot the learning curve and decision boundary.
#
# All of these steps are described in detail in the following sections.

# %% [markdown]
# ## How to use Google Colaboratory (Colab)

# %% [markdown]
# Google Colaboratory (also known as Google Colab) is a platform that allows you to run Python code in your browser. The code is written in *cells* that are executed on a remote server.
#
# To run a cell, hover over a cell and click on the `run` button to its left. The run button is the circle with the triangle (▶). Alternatively, you can also click on a cell and use the keyboard combination Ctrl+Return (or ⌘+Return if you are using a Mac).
#
# To try this out, run the following cell. This should print today's day of the week below it.

# %%
from datetime import datetime

print(f"Today is {datetime.today():%A}.")
# Out:
# Today is Wednesday.

# %% [markdown]
# Note that the order in which you run the cells matters. When you are working through a lab, make sure to always run all cells in order, otherwise the code might not work. If you take a break while working on a lab, Colab may disconnect you and in that case, you have to execute all cells again before  continuing your work. To make this easier, you can select the cell you are currently working on and then choose __Runtime → Run before__  from the menu above (or use the keyboard combination Ctrl/⌘ + F8). This will re-execute all cells before the current one.

# %% [markdown]
# ## Imports
#
# In this lab, you will primarily use functions from the custom `ai_foundations` package for training the model and for creating plots.
#
# Run the following cell to import all required packages.

# %%
# %%capture
# Install the custom package for this course.
# !pip install "git+https://github.com/google-deepmind/ai-foundations.git@main"

import os # For adjusting Keras settings.
os.environ['KERAS_BACKEND'] = 'jax' # Set a parameter for Keras.

# Packages used.
import jax.numpy as jnp # For defining matrices.
import keras # For adjusting Keras settings.
import pandas as pd # For loading the dataset.

from ai_foundations import machine_learning # For defining and training MLPs.
from ai_foundations import visualizations # For visualizing data and boundaries.
from ai_foundations import training # For logging the loss during training.

# %% [markdown]
# ## Load the dataset
#
# Run the following cell to load the dataset and prepare the `jax.Arrays` with the training and test data. Note that the data here is manually split into a training set and a test set such that the most challenging examples (all outliers) appear in the test set. This will make it easier to see some of the differences that come from training models with different hyperparameters.

# %%
# Load data using pandas.
df = pd.read_csv("https://storage.googleapis.com/dm-educational/assets/ai_foundations/mat-apple-bank-dataset.csv")

# Extract embeddings (Embedding_dim_1, Embedding_dim_2) and labels.
X = jnp.array(df[["Embedding_dim_1", "Embedding_dim_2"]].values)
# Labels: 0 ("mat"), 1 ("apple"), or 2 ("bank").
y = jnp.array(df["Label"].values)

# Human-readable labels.
labels = ["mat", "apple", "bank"]

# Manually split the data.
X_train, X_test, y_train, y_test = X[0:61, :], X[61:, :], y[0:61], y[61:]

# %% [markdown]
# ## Optimizing hyperparameters
#
# -----
# > **💻 Your task:**
# >
# >As mentioned above, you will experiment here with networks that differ in terms of:
# > * the number of layers
# > * the dimensions of each layer (how many neurons there are in each layer)
# >
# >In general, the more layers you add and the larger the hidden layer dimensions are, the more likely the model will overfit.
# >
# >On the other hand, if you use very few hidden layers (e.g., just one) with a very low dimension (e.g., just 2 neurons), the model will likely not learn a good decision function and underfit.
# >
# >Importantly, you will keep everything but the number of layers and the dimensions of the layers constant in this exercise. For example, the number of epochs will be the same across all runs. This allows you to directly attribute any differences in model performance to the hyperparameters that you change.
# >
# >Use the cells below to define different network structures by changing `hidden_dims`.
# >
# >Then:
# >1. Visualize the structure of the network to get a sense of what it looks like.
# >2. Train the network on the dataset.
# >3. Visualize the decision boundary and observe the train and test accuracies. Recall that the accuracy is defined as the percentage of examples for which the model makes the correct predictions. The train accuracy indicates whether the model learned something — low train accuracy suggests **underfitting**. The test accuracy indicates whether the model is able to generalize — low test accuracy in combination with high train accuracy suggests **overfitting**.
# >
# >
# >Repeat these three steps with at least three network configurations, that is three different settings of `hidden_dims`.
# >
# >Make sure to train:
# >1. one network with only one layer and a very low number of neurons
# >2. one network that has at least three layers and the first layer has more than 1,000 neurons
# >3. one network with settings somewhere in between
# >
# >Which ones of these seem to suffer from overfitting? Which ones from underfitting? Can you find settings for which the model seems to generalize well?
# -----

# %%
# Set the number of hidden layers and their dimensions here.
# Each number indicates the number of neurons per layer. For example, setting
# this to `[20, 10]` will initialze an MLP with two hidden layers of dimensions
# 20 and 10, respectively.
hidden_dims = [20, 10]

# Initialize the model and visualize its structure.
mlp_model = machine_learning.build_mlp(hidden_dims=hidden_dims, n_classes=3)
visualizations.visualize_mlp_architecture(hidden_dims, 3)

# Train the model.
training_logger = training.CustomAccuracyPrinter(print_every=20)
training_history = machine_learning.train_mlp(
    mlp_model,
    X_train,
    y_train,
    learning_rate=0.005,
    validation_data=(X_test, y_test),
    epochs=500,
    callbacks=[training_logger],
)

# Plot the loss curve.
visualizations.plot_loss_curve(training_history.history)

# Compute the accuracy and visualize the decision boundaries.
train_acc = training_history.history["accuracy"][-1]
test_acc = training_history.history["val_accuracy"][-1]

print(f"Train accuracy: {train_acc * 100:.2f}%")
print(f"Test accuracy: {test_acc * 100:.2f}%")

visualizations.plot_data_and_mlp(
    X_train,
    y_train,
    labels,
    features_test=X_test,
    label_ids_test=y_test,
    mlp_model=mlp_model,
    title="Decision Boundaries - Your MLP",
)
# Out:
# Epoch 19: Training loss: 0.41857, training accuracy: 78.69%, test loss: 0.53274, test accuracy: 75.00%
# Epoch 39: Training loss: 0.30420, training accuracy: 78.69%, test loss: 0.39371, test accuracy: 75.00%
# Epoch 59: Training loss: 0.22399, training accuracy: 91.80%, test loss: 0.30261, test accuracy: 91.67%
# Epoch 79: Training loss: 0.14118, training accuracy: 98.36%, test loss: 0.22593, test accuracy: 100.00%
# Epoch 99: Training loss: 0.07220, training accuracy: 100.00%, test loss: 0.16575, test accuracy: 100.00%
# Epoch 119: Training loss: 0.03577, training accuracy: 100.00%, test loss: 0.12714, test accuracy: 100.00%
# Epoch 139: Training loss: 0.01996, training accuracy: 100.00%, test loss: 0.10277, test accuracy: 100.00%
# Epoch 159: Training loss: 0.01252, training accuracy: 100.00%, test loss: 0.08750, test accuracy: 100.00%
# Epoch 179: Training loss: 0.00863, training accuracy: 100.00%, test loss: 0.07960, test accuracy: 100.00%
# Epoch 199: Training loss: 0.00625, training accuracy: 100.00%, test loss: 0.07378, test accuracy: 100.00%
# Epoch 219: Training loss: 0.00475, training accuracy: 100.00%, test loss: 0.07124, test accuracy: 100.00%
# Epoch 239: Training loss: 0.00374, training accuracy: 100.00%, test loss: 0.07036, test accuracy: 100.00%
# Epoch 259: Training loss: 0.00302, training accuracy: 100.00%, test loss: 0.06956, test accuracy: 100.00%
# Epoch 279: Training loss: 0.00249, training accuracy: 100.00%, test loss: 0.06954, test accuracy: 100.00%
# Epoch 299: Training loss: 0.00209, training accuracy: 100.00%, test loss: 0.07011, test accuracy: 100.00%
# Epoch 319: Training loss: 0.00178, training accuracy: 100.00%, test loss: 0.07024, test accuracy: 100.00%
# Epoch 339: Training loss: 0.00154, training accuracy: 100.00%, test loss: 0.06994, test accuracy: 100.00%
# Epoch 359: Training loss: 0.00135, training accuracy: 100.00%, test loss: 0.07037, test accuracy: 100.00%
# Epoch 379: Training loss: 0.00119, training accuracy: 100.00%, test loss: 0.06994, test accuracy: 100.00%
# Epoch 399: Training loss: 0.00106, training accuracy: 100.00%, test loss: 0.06923, test accuracy: 100.00%
# Epoch 419: Training loss: 0.00095, training accuracy: 100.00%, test loss: 0.06878, test accuracy: 100.00%
# Epoch 439: Training loss: 0.00086, training accuracy: 100.00%, test loss: 0.06854, test accuracy: 100.00%
# Epoch 459: Training loss: 0.00078, training accuracy: 100.00%, test loss: 0.06870, test accuracy: 100.00%
# Epoch 479: Training loss: 0.00071, training accuracy: 100.00%, test loss: 0.06895, test accuracy: 100.00%
# Epoch 499: Training loss: 0.00065, training accuracy: 100.00%, test loss: 0.06892, test accuracy: 100.00%
# Train accuracy: 100.00%
# Test accuracy: 100.00%

# %% [markdown]
# ### Configuration 1: Underfitting Model (1 layer, 2 neurons)

# %%
# Set the number of hidden layers and their dimensions for an underfitting model.
hidden_dims_underfit = [2]

# Initialize the model and visualize its structure.
mlp_model_underfit = machine_learning.build_mlp(hidden_dims=hidden_dims_underfit, n_classes=3)
visualizations.visualize_mlp_architecture(hidden_dims_underfit, 3)

# Train the model.
training_logger_underfit = training.CustomAccuracyPrinter(print_every=20)
training_history_underfit = machine_learning.train_mlp(
    mlp_model_underfit,
    X_train,
    y_train,
    learning_rate=0.005,
    validation_data=(X_test, y_test),
    epochs=500,
    callbacks=[training_logger_underfit],
)

# Plot the loss curve.
visualizations.plot_loss_curve(training_history_underfit.history)

# Compute the accuracy and visualize the decision boundaries.
train_acc_underfit = training_history_underfit.history["accuracy"][-1]
test_acc_underfit = training_history_underfit.history["val_accuracy"][-1]

print(f"Train accuracy (Underfitting Model): {train_acc_underfit * 100:.2f}%")
print(f"Test accuracy (Underfitting Model): {test_acc_underfit * 100:.2f}%")

visualizations.plot_data_and_mlp(
    X_train,
    y_train,
    labels,
    features_test=X_test,
    label_ids_test=y_test,
    mlp_model=mlp_model_underfit,
    title="Decision Boundaries - Underfitting MLP",
)
# Out:
# Epoch 19: Training loss: 1.10250, training accuracy: 47.54%, test loss: 1.10527, test accuracy: 50.00%
# Epoch 39: Training loss: 0.94163, training accuracy: 65.57%, test loss: 0.95474, test accuracy: 50.00%
# Epoch 59: Training loss: 0.87013, training accuracy: 65.57%, test loss: 0.89918, test accuracy: 50.00%
# Epoch 79: Training loss: 0.82343, training accuracy: 59.02%, test loss: 0.85748, test accuracy: 50.00%
# Epoch 99: Training loss: 0.77930, training accuracy: 62.30%, test loss: 0.81877, test accuracy: 66.67%
# Epoch 119: Training loss: 0.73666, training accuracy: 62.30%, test loss: 0.78523, test accuracy: 58.33%
# Epoch 139: Training loss: 0.69235, training accuracy: 67.21%, test loss: 0.75281, test accuracy: 58.33%
# Epoch 159: Training loss: 0.64705, training accuracy: 70.49%, test loss: 0.71749, test accuracy: 66.67%
# Epoch 179: Training loss: 0.60109, training accuracy: 72.13%, test loss: 0.67679, test accuracy: 66.67%
# Epoch 199: Training loss: 0.55763, training accuracy: 73.77%, test loss: 0.63966, test accuracy: 66.67%
# Epoch 219: Training loss: 0.51990, training accuracy: 73.77%, test loss: 0.60337, test accuracy: 66.67%
# Epoch 239: Training loss: 0.48793, training accuracy: 77.05%, test loss: 0.57024, test accuracy: 75.00%
# Epoch 259: Training loss: 0.46041, training accuracy: 77.05%, test loss: 0.54053, test accuracy: 75.00%
# Epoch 279: Training loss: 0.43632, training accuracy: 77.05%, test loss: 0.51554, test accuracy: 75.00%
# Epoch 299: Training loss: 0.41565, training accuracy: 77.05%, test loss: 0.49289, test accuracy: 75.00%
# Epoch 319: Training loss: 0.39769, training accuracy: 77.05%, test loss: 0.47382, test accuracy: 75.00%
# Epoch 339: Training loss: 0.38193, training accuracy: 93.44%, test loss: 0.45791, test accuracy: 100.00%
# Epoch 359: Training loss: 0.36790, training accuracy: 95.08%, test loss: 0.44464, test accuracy: 100.00%
# Epoch 379: Training loss: 0.35508, training accuracy: 95.08%, test loss: 0.43352, test accuracy: 91.67%
# Epoch 399: Training loss: 0.34333, training accuracy: 96.72%, test loss: 0.42215, test accuracy: 91.67%
# Epoch 419: Training loss: 0.33215, training accuracy: 98.36%, test loss: 0.41160, test accuracy: 91.67%
# Epoch 439: Training loss: 0.32114, training accuracy: 98.36%, test loss: 0.40172, test accuracy: 91.67%
# Epoch 459: Training loss: 0.31001, training accuracy: 98.36%, test loss: 0.39158, test accuracy: 91.67%
# Epoch 479: Training loss: 0.29846, training accuracy: 98.36%, test loss: 0.38085, test accuracy: 100.00%
# Epoch 499: Training loss: 0.28635, training accuracy: 98.36%, test loss: 0.36867, test accuracy: 100.00%
# Train accuracy (Underfitting Model): 98.36%
# Test accuracy (Underfitting Model): 100.00%

# %% [markdown]
# ### Configuration 2: Overfitting Model (3+ layers, first layer > 1000 neurons)

# %%
# Set the number of hidden layers and their dimensions for an overfitting model.
hidden_dims_overfit = [1000, 500, 200]

# Initialize the model and visualize its structure.
mlp_model_overfit = machine_learning.build_mlp(hidden_dims=hidden_dims_overfit, n_classes=3)
visualizations.visualize_mlp_architecture(hidden_dims_overfit, 3)

# Train the model.
training_logger_overfit = training.CustomAccuracyPrinter(print_every=20)
training_history_overfit = machine_learning.train_mlp(
    mlp_model_overfit,
    X_train,
    y_train,
    learning_rate=0.005,
    validation_data=(X_test, y_test),
    epochs=500,
    callbacks=[training_logger_overfit],
)

# Plot the loss curve.
visualizations.plot_loss_curve(training_history_overfit.history)

# Compute the accuracy and visualize the decision boundaries.
train_acc_overfit = training_history_overfit.history["accuracy"][-1]
test_acc_overfit = training_history_overfit.history["val_accuracy"][-1]

print(f"Train accuracy (Overfitting Model): {train_acc_overfit * 100:.2f}%")
print(f"Test accuracy (Overfitting Model): {test_acc_overfit * 100:.2f}%")

visualizations.plot_data_and_mlp(
    X_train,
    y_train,
    labels,
    features_test=X_test,
    label_ids_test=y_test,
    mlp_model=mlp_model_overfit,
    title="Decision Boundaries - Overfitting MLP",
)
# Out:
# Epoch 19: Training loss: 0.00039, training accuracy: 100.00%, test loss: 0.08415, test accuracy: 91.67%
# Epoch 39: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.29798, test accuracy: 91.67%
# Epoch 59: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.24595, test accuracy: 91.67%
# Epoch 79: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.21772, test accuracy: 91.67%
# Epoch 99: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.20012, test accuracy: 91.67%
# Epoch 119: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.18487, test accuracy: 91.67%
# Epoch 139: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.17268, test accuracy: 91.67%
# Epoch 159: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.16161, test accuracy: 91.67%
# Epoch 179: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.15269, test accuracy: 91.67%
# Epoch 199: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.14494, test accuracy: 91.67%
# Epoch 219: Training loss: 0.00001, training accuracy: 100.00%, test loss: 0.13805, test accuracy: 91.67%
# Epoch 239: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.13196, test accuracy: 91.67%
# Epoch 259: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.12739, test accuracy: 91.67%
# Epoch 279: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.12265, test accuracy: 91.67%
# Epoch 299: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.11820, test accuracy: 91.67%
# Epoch 319: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.11469, test accuracy: 91.67%
# Epoch 339: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.11136, test accuracy: 91.67%
# Epoch 359: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.10833, test accuracy: 91.67%
# Epoch 379: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.10570, test accuracy: 91.67%
# Epoch 399: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.10303, test accuracy: 91.67%
# Epoch 419: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.10037, test accuracy: 91.67%
# Epoch 439: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.09806, test accuracy: 91.67%
# Epoch 459: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.09542, test accuracy: 91.67%
# Epoch 479: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.09321, test accuracy: 91.67%
# Epoch 499: Training loss: 0.00000, training accuracy: 100.00%, test loss: 0.09141, test accuracy: 91.67%
# Train accuracy (Overfitting Model): 100.00%
# Test accuracy (Overfitting Model): 91.67%

# %% [markdown]
# ### Summary of Observations
#
# Based on the configurations run (including the initial one with `hidden_dims = [20, 10]`):
#
# **Underfitting Model (e.g., `hidden_dims = [2]`):**
# *   **Loss Curves:** Both training and validation loss will likely remain high and may not decrease significantly. This indicates the model struggles to learn the underlying patterns in the data.
# *   **Accuracies:** Both training and test accuracies will be low. The model lacks the capacity to fit the training data well, leading to poor performance on unseen data too.
# *   **Decision Boundaries:** The decision boundaries will appear very simple, possibly straight lines, unable to effectively separate the different classes.
#
# **Good Generalization Model (e.g., `hidden_dims = [20, 10]`):**
# *   **Loss Curves:** Both training and validation loss decrease steadily and converge to a low value, staying close to each other. This indicates the model is learning well and generalizing.
# *   **Accuracies:** Both training and test accuracies will be high and close to each other, often reaching 100% on this simple dataset. This shows the model effectively learned the patterns without memorizing noise.
# *   **Decision Boundaries:** The decision boundaries will be reasonably complex, effectively separating the classes in both training and test sets.
#
# **Overfitting Model (e.g., `hidden_dims = [1000, 500, 200]`):**
# *   **Loss Curves:** Training loss will decrease very rapidly, possibly reaching near zero, while validation loss might decrease initially but then start to increase or fluctuate more, indicating a divergence. The training loss will be significantly lower than the validation loss.
# *   **Accuracies:** Training accuracy will be very high (often 100%), but test accuracy will be lower than training accuracy. The model has learned the training data too well, including its noise, and struggles to generalize to new, unseen data.
# *   **Decision Boundaries:** The decision boundaries will be highly irregular and complex, twisting to perfectly encapsulate individual training points, which makes them less effective on test data.
#
# In essence, finding the right hyperparameters involves balancing model capacity to avoid both underfitting (too simple) and overfitting (too complex), aiming for optimal generalization to new data.

# %% [markdown]
# ### What did you observe?
#
# You likely noticed that when you trained a network with a single hidden layer with very few neurons that it had both a low training and test accuracy. This is a classic sign of **underfitting**. The model did not have enough capacity to learn complex enough decision boundaries and therefore was not able to separate the data points.
#
# When you trained a network with multiple layers, at least one of which was very large, you probably noticed that the decision boundary was a really complex shape and the test accuracy was lower than the train accuracy (though probably still quite high, since this dataset is not too complex). This indicates **overfitting**. The model has so many parameters that instead of only learning useful patterns from the training data (the signal), it also learned patterns specific to these training examples (the noise). This hindered its ability to generalize to examples in the test set.
#
# Finally, when you specified a model with a more reasonable number of parameters (e.g., a layer of 10 neurons and a layer of 5 neurons), you likely observed that it managed to learn a decision boundary that worked well for both the examples in the training set and the examples in the held-out test set. A model such as this is better able to generalize.

# %% [markdown]
# ## Summary
# In this activity, you explored how the size of your neural network affects learning.
#
# You changed two hyperparameters:
#
# * The number of hidden layers
# * The number of neurons in each layer
#
# By testing different model sizes, you saw three possible outcomes:
#
# - Underfitting: Small models could not learn enough patterns. Both training and test loss stayed high.
# - Overfitting: Very large models learned patterns from the training data perfectly, but did not perform as well on the test data and they did not generalize well.
# - Good: Medium-sized models learned well and worked well on new data.
#
# You also visualized:
# - Loss curves to track how the model learned over time.
# - Decision boundaries to see how the model separates different classes.
#
# In the next activity, you will learn more about additional techniques to mitigate overfitting.
